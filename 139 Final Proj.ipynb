# %%
import pandas as pd
import numpy as np

# %%
#read in ffdata
ffdata = pd.read_csv("ffdata.txt", delim_whitespace=True)
ffdata
# Out:
#       -0.000800  0.008300  0.004100  0.000040
# 0        0.0122    0.0035    0.0002   0.00004
# 1        0.0019    0.0012    0.0018   0.00004
# 2        0.0027    0.0050   -0.0007   0.00004
# 3        0.0048    0.0033    0.0062   0.00004
# 4       -0.0063    0.0003    0.0027   0.00004
# ...         ...       ...       ...       ...
# 1505     0.0052   -0.0008    0.0016   0.00000
# 1506     0.0010   -0.0015   -0.0030   0.00000
# 1507    -0.0009    0.0008   -0.0008   0.00000
# 1508    -0.0007   -0.0004   -0.0018   0.00000
# 1509    -0.0088   -0.0013    0.0015   0.00000
#
# [1510 rows x 4 columns]

# %%
#load in ticker.txt - tickers
ticker = pd.read_csv('ticker.txt', header=None)
ticker = ticker.reset_index()
ticker['index'] = ticker['index'] + 1
ticker
# Out:
#       index     0
# 0         1     A
# 1         2    AA
# 2         3   AAI
# 3         4  AAON
# 4         5   AAP
# ...     ...   ...
# 1872   1873   ZMH
# 1873   1874  ZOLL
# 1874   1875  ZOLT
# 1875   1876   ZQK
# 1876   1877  ZRAN
#
# [1877 rows x 2 columns]

# %%
#load in retdate.txt - return dates
retdate = pd.read_csv('retdate.txt', sep = " ", header = None)
retdate[0]
# Out:
# 0       20040102
# 1       20040105
# 2       20040106
# 3       20040107
# 4       20040108
#           ...
# 1506    20091224
# 1507    20091228
# 1508    20091229
# 1509    20091230
# 1510    20091231
# Name: 0, Length: 1511, dtype: int64

# %%
#load in secdata.txt - securities data
secdata = pd.read_csv('secdata.txt', sep = " ", header = None)
secdata.columns = ['Ticker #', 'Stock Returns', 'Market Capitalizations']
secdata
# Out:
#          Ticker #  Stock Returns  Market Capitalizations
# 0               1      -0.015048             13713091.20
# 1               1       0.026042             14070202.95
# 2               1       0.031472             14513021.52
# 3               1       0.012795             14698719.63
# 4               1       0.045675             15370089.72
# ...           ...            ...                     ...
# 2836142      1877       0.000000               580951.00
# 2836143      1877      -0.008079               576257.50
# 2836144      1877       0.000000               576257.50
# 2836145      1877       0.008145               580951.00
# 2836146      1877      -0.008079               576257.50
#
# [2836147 rows x 3 columns]

# %%
#merge ticker with stocks
stock_with_ticker = secdata.merge(ticker, left_on = "Ticker #", right_on = "index")
stock_with_ticker.to_csv('stock_with_ticker.csv')

# %% [markdown]
# # Question 2
#
# We now consider the modern portfolio theory (MPT) approach to estimating volatility. Each step below should be completed using 504, 252, 126, and 63 day rolling windows.

# %% [markdown]
# ## a) Pick a portfolio of 100 securities.
#
# Criteria: Security numbers chosen at random between 1-1877.

# %%
secdata
# Out:
#          Ticker #  Stock Returns  Market Capitalizations
# 0               1      -0.015048             13713091.20
# 1               1       0.026042             14070202.95
# 2               1       0.031472             14513021.52
# 3               1       0.012795             14698719.63
# 4               1       0.045675             15370089.72
# ...           ...            ...                     ...
# 2836142      1877       0.000000               580951.00
# 2836143      1877      -0.008079               576257.50
# 2836144      1877       0.000000               576257.50
# 2836145      1877       0.008145               580951.00
# 2836146      1877      -0.008079               576257.50
#
# [2836147 rows x 3 columns]

# %%
random_tickers = list(np.random.choice(1511, 100))

# %%
#turn tickers into columns
secdata_group = secdata.set_index([secdata.groupby('Ticker #').cumcount(), 'Ticker #'])['Stock Returns'].unstack()
secdata_group
# Out:
# Ticker #      1         2         3         4         5         6     \
# 0        -0.015048 -0.011842  0.030252 -0.024729  0.000246 -0.004212
# 1         0.026042  0.032756  0.008157  0.004754 -0.009089  0.041823
# 2         0.031472 -0.007478  0.062298  0.014196  0.017848 -0.003608
# 3         0.012795 -0.007534  0.022848 -0.005184  0.031417  0.022635
# 4         0.045675  0.012042 -0.067014  0.001042 -0.026446  0.034086
# ...            ...       ...       ...       ...       ...       ...
# 1506      0.000990  0.021250  0.009363  0.011190  0.000242  0.034339
# 1507      0.002308 -0.014688 -0.035250 -0.010060 -0.003867  0.012294
# 1508     -0.002303 -0.004348 -0.007692  0.013720 -0.011160 -0.011861
# 1509      0.025387  0.016843  0.007752 -0.005013  0.006133  0.012147
# 1510     -0.000965 -0.011043  0.003846 -0.018136 -0.012924 -0.004290
#
# Ticker #      7         8         9         10    ...      1868      1869  \
# 0        -0.072416 -0.038290  0.011801 -0.004594  ... -0.012180  0.048387
# 1        -0.072706  0.033889  0.016574  0.003750  ... -0.093711  0.030154
# 2         0.097044 -0.004120  0.006099  0.002299  ...  0.072109  0.020311
# 3         0.062683  0.009712  0.012544 -0.001433  ... -0.081218  0.004040
# 4         0.006064 -0.004809  0.007706 -0.024117  ...  0.019337  0.049624
# ...            ...       ...       ...       ...  ...       ...       ...
# 1506      0.019135  0.000760  0.004438  0.005749  ...  0.017206 -0.003236
# 1507      0.016327  0.002658  0.032401 -0.000336  ... -0.020706  0.022727
# 1508      0.012450 -0.001515  0.013442  0.009082  ... -0.011912  0.011111
# 1509      0.015470 -0.002275  0.011348  0.018667  ... -0.005425 -0.003140
# 1510     -0.001953 -0.009122  0.004208  0.002945  ... -0.012727  0.006299
#
# Ticker #      1870      1871      1872      1873      1874      1875  \
# 0         0.023044 -0.018585 -0.054085 -0.005682  0.004520  0.039604
# 1        -0.004742 -0.002159  0.046229 -0.009000  0.012655 -0.007619
# 2         0.021441  0.013817  0.063953 -0.004901  0.002499  0.038196
# 3         0.010496 -0.006897 -0.015300  0.011155  0.003601  0.053799
# 4         0.047317  0.005291  0.018868  0.019341  0.026497 -0.052632
# ...            ...       ...       ...       ...       ...       ...
# 1506      0.022831 -0.001548  0.005747  0.003329 -0.001074  0.002101
# 1507      0.022321 -0.010853  0.011429  0.001161  0.005733  0.044025
# 1508     -0.014556 -0.000784 -0.022599 -0.002652 -0.011756 -0.012048
# 1509      0.008863  0.003922 -0.011561 -0.006979 -0.019106 -0.014228
# 1510     -0.014641  0.002344  0.000000 -0.010877 -0.018008 -0.020619
#
# Ticker #      1876      1877
# 0        -0.007332  0.019551
# 1         0.006250  0.048505
# 2         0.002259  0.054061
# 3        -0.002817  0.009441
# 4        -0.000565 -0.001517
# ...            ...       ...
# 1506     -0.046808  0.000000
# 1507     -0.040179 -0.008079
# 1508      0.013953  0.000000
# 1509     -0.050459  0.008145
# $$ \hat{\sigma}_{Portfolio} = \sqrt{w_{T} \cdot \Sigma \cdot w}$$
#
# where:
# - $w$ is portfolio weights
# - $\Sigma$ is covariance matrix
# - $\cdot$ the dot-multiplication for matrix multiplication
# - $\hat{\sigma}_{Portfolio}$ is the estimated portfolio volatility/standard deviation

# %%
#function to find portfolio standard deviation
def sd_portfolio(cov_mat, arr_weights):
    if np.isnan(cov_mat).any():
        return cov_mat
    return np.dot(np.dot(np.transpose(arr_weights), cov_mat), arr_weights)**0.5

# %% [markdown]
# ### Rolling Window 504

# %% [markdown]
# #### i) Generate a covariance matrixes for generated portfolio.

# %%
cov_df_504 = portfolio_q2_ret.rolling(504).cov()
cov_df_504.dropna(inplace = True)
cov_df_504.drop(cov_df_504.tail(100).index, inplace = True)
cov_df_504_np = cov_df_504.to_numpy()
cov_df_504
# Out:
# Ticker #           861       895       747       1183      1389      495   \
#      Ticker #
# 503  861       0.000253  0.000047  0.000010  0.000010  0.000056  0.000052
#      895       0.000047  0.000758 -0.000015  0.000162  0.000178  0.000127
#      747       0.000010 -0.000015  0.001621  0.000120  0.000018  0.000070
#      1183      0.000010  0.000162  0.000120  0.000734  0.000149  0.000118
#      1389      0.000056  0.000178  0.000018  0.000149  0.000690  0.000108
# ...                 ...       ...       ...       ...       ...       ...
# 1509 1196      0.000435  0.000503  0.000801  0.000385  0.000679  0.000321
#      163       0.000481  0.000668  0.000702  0.000412  0.000574  0.000281
#      388       0.000594  0.000669  0.001035  0.000546  0.000719  0.000330
#      610       0.000865  0.001076  0.001356  0.000896  0.001059  0.000442
#      304       0.000638  0.000808  0.000966  0.000513  0.000860  0.000368
#
# Ticker #           729       656       1479      675   ...      1113  \
#      Ticker #                                          ...
# 503  861       0.000031  0.000024  0.000061 -0.000024  ...  0.000108
#      895       0.000121  0.000036  0.000045  0.000057  ...  0.000074
#      747       0.000138  0.000092  0.000046  0.000079  ...  0.000083
#      1183      0.000112  0.000080  0.000055  0.000076  ...  0.000061
#      1389      0.000074  0.000051  0.000045  0.000084  ...  0.000184
# ...                 ...       ...       ...       ...  ...       ...
# 1509 1196      0.000851  0.000542  0.001029  0.000814  ...  0.000716
#      163       0.000877  0.000564  0.000823  0.000718  ...  0.000809
#      388       0.001112  0.000697  0.001101  0.000992  ...  0.000945
#      610       0.001989  0.001171  0.001336  0.001437  ...  0.001420
#      304       0.001297  0.000715  0.001149  0.001197  ...  0.001163
#
# Ticker #           505       189       910       1502      1196      163   \
#      Ticker #
# 503  861       0.000033  0.000003  0.000073  0.000017  0.000026  0.000033
#      895       0.000085  0.000056  0.000226  0.000056  0.000081  0.000216
#      747       0.000056  0.000043  0.000107  0.000041  0.000058 -0.000006
#      1183      0.000160  0.000140  0.000156  0.000073  0.000086  0.000137
#      1389      0.000130  0.000080  0.000199  0.000062  0.000058  0.000161
# ...                 ...       ...       ...       ...       ...       ...
# 1509 1196      0.001030  0.000530  0.000514  0.000354  0.001359  0.000482
#      163       0.000977  0.000860  0.000552  0.000254  0.000482  0.001036
#      388       0.001252  0.001174  0.000478  0.000365  0.000667  0.000783
#      610       0.001775  0.001147  0.000911  0.000440  0.001208  0.000945
#      304       0.001277  0.001044  0.000760  0.000420  0.000788  0.000822
#
# Ticker #           388       610       304
#      Ticker #
# 503  861       0.000066  0.000026  0.000053
#      895       0.000280  0.000101  0.000172
#      747       0.000193  0.000069  0.000032
#      1183      0.000206  0.000088  0.000060
#      1389      0.000214  0.000102  0.000159
# ...                 ...       ...       ...
# 1509 1196      0.000667  0.001208  0.000788
#      163       0.000783  0.000945  0.000822
#      388       0.002377  0.001273  0.001017
#      610       0.001273  0.005741  0.001355
#      304       0.001017  0.001355  0.001942
#
# [100700 rows x 100 columns]

# %% [markdown]
# #### ii) Estimate the standard deviations of the portfolio over rw (from the last day in the rolling window).

# %%
#portfolio_weights
weights_q2_504 = portfolio_q2_cap.iloc[:, :].apply(lambda x: x.div(x.sum()), axis=1)
df_weights_q2_504 = weights_q2_504.drop(weights_q2_504.tail(1).index)
arr_weights_q2_504 = df_weights_q2_504.tail(1007).to_numpy()
df_weights_q2_504
# Out:
# Ticker #      861       895       747       1183      1389      495   \
# 0         0.004805  0.011026  0.000114  0.002565  0.000906  0.004899
# 1         0.004812  0.011038  0.000110  0.002542  0.000956  0.004859
# 2         0.005343  0.011223  0.000118  0.002563  0.000968  0.005227
# 3         0.005049  0.011096  0.000114  0.002650  0.000982  0.005199
# 4         0.005130  0.011688  0.000106  0.002670  0.001099  0.005264
# ...            ...       ...       ...       ...       ...       ...
# 1505      0.007734  0.022400  0.000624  0.004414  0.001582  0.007035
# 1506      0.007695  0.022449  0.000625  0.004420  0.001572  0.006995
# 1507      0.007622  0.022722  0.000605  0.004393  0.001565  0.006964
# 1508      0.007640  0.022801  0.000608  0.004395  0.001587  0.006949
# 1509      0.007562  0.023055  0.000593  0.004353  0.001596  0.006946
#
# Ticker #      729       656       1479      675   ...      1113      505   \
# 0         0.000261  0.014763  0.002665  0.000100  ...  0.000431  0.000231
# 1         0.000261  0.014413  0.002644  0.000097  ...  0.000458  0.000234
# 2         0.000253  0.014403  0.002635  0.000099  ...  0.000475  0.000219
# 3         0.000242  0.014251  0.002623  0.000099  ...  0.000455  0.000243
# 4         0.000250  0.014111  0.002622  0.000103  ...  0.000377  0.000259
# ...            ...       ...       ...       ...  ...       ...       ...
# 1505      0.000201  0.010435  0.003216  0.000304  ...  0.000448  0.000612
# 1506      0.000199  0.010402  0.003235  0.000298  ...  0.000447  0.000528
# 1507      0.000201  0.010451  0.003208  0.000300  ...  0.000445  0.000545
# 1508      0.000203  0.010533  0.003254  0.000300  ...  0.000443  0.000533
# 1509      0.000198  0.010522  0.003245  0.000308  ...  0.000452  0.000506
#
# Ticker #      189       910       1502      1196      163       388   \
# 0         0.000170  0.000359  0.000754  0.010359  0.003666  0.000518
# 1         0.000166  0.000384  0.000754  0.010232  0.003679  0.000533
# 2         0.000166  0.000403  0.000748  0.010305  0.003674  0.000570
# 3         0.000164  0.000397  0.000745  0.010193  0.003594  0.000599
# 4         0.000169  0.000399  0.000747  0.010232  0.003723  0.000599
# ...            ...       ...       ...       ...       ...       ...
# 1505      0.000438  0.000096  0.001869  0.008487  0.007285  0.001209
# 1506      0.000485  0.000098  0.001866  0.008484  0.007287  0.001204
# 1507      0.000474  0.000099  0.001893  0.008318  0.007267  0.001187
# 1508      0.000460  0.000101  0.001917  0.008390  0.007276  0.001193
# 1509      0.000457  0.000100  0.001894  0.008404  0.007440  0.001184
#
# Ticker #      610       304
# 0         0.002275  0.000487
# 1         0.002270  0.000511
# 2         0.002260  0.000527
# 3         0.002263  0.000513
# 4         0.002286  0.000543
# ...            ...       ...
# 1505      0.000407  0.000931
# 1506      0.000434  0.000948
# 1507      0.000422  0.000948
# 1508      0.000430  0.000947
# 1509      0.000431  0.000955
#
# [1510 rows x 100 columns]

# %%
sd_port_504 = []
for i in range(0, len(cov_df_504_np), 100):
    idx = 0
    sd_port_504.append(sd_portfolio(cov_df_504_np[i:i+100], arr_weights_q2_504[idx]))
    idx += 1
sd_port_504_arr = np.array(sd_port_504)
sd_port_504_arr
# Out:
# array([0.00778539, 0.0078214 , 0.00781648, ..., 0.03085613, 0.03085523,
#        0.03085458])

# %% [markdown]
# #### iii) Using the market capitalization weights and returns (from the day following the last day in the rolling window) of your securities, calculate the one-day ahead return of the portfolio, $\tilde{r}_{p}$.

# %%
#getting one-day ahead returns array
dayahead504_port_ret_q2 = []
dayahead504_ret_q2 = portfolio_q2_ret.loc[504:1510].to_numpy()
dayahead504_w_q2 = weights_q2_504.loc[504:1510].to_numpy()
for i in range(0, len(dayahead504_w_q2)):
    dayahead504_port_ret_q2.append(np.multiply(dayahead504_ret_q2[i], dayahead504_w_q2[i]))
dayahead504_port_ret_q2_arr = np.sum(np.array(dayahead504_port_ret_q2), axis = 1)
dayahead504_port_ret_q2_arr
# Out:
# array([ 0.01755353,  0.00136112,  0.00178823, ..., -0.0022362 ,
#         0.0004401 , -0.00969607])

# %% [markdown]
# #### iv) Calculate the standardized outcome, $\tilde{z}_{p}$, where $\tilde{z}_{p} = \frac{\tilde{r}_{p}}{\hat{\sigma}_{p}}$ where we make the simplifying assumption that $E[\tilde{r}_{p}] = 0$.

# %%
#dividing arrays to get standardized outcomes.
standardized_outcomes_504_q2 = dayahead504_port_ret_q2_arr / sd_port_504_arr
std_outcomes_504_q2 = pd.DataFrame(standardized_outcomes_504_q2)
std_outcomes_504_q2.index += 504
std_outcomes_504_q2.rename(columns={0: "Standardized Outcome"}, inplace = True)
std_outcomes_504_q2
# Out:
#       Standardized Outcome
# 504               2.254676
# 505               0.174026
# 506               0.228777
# 507               0.402387
# 508               0.603898
# ...                    ...
# 1506              0.190636
# 1507              0.060392
# 1508             -0.072472
# 1509              0.014263
# 1510             -0.314250
#
# [1007 rows x 1 columns]

# %% [markdown]
# ### Rolling Window 252

# %% [markdown]
# #### i) Generate a covariance matrixes for generated portfolio.

# %%
cov_df_252 = portfolio_q2_ret.rolling(252).cov()
cov_df_252.dropna(inplace = True)
cov_df_252.drop(cov_df_252.tail(100).index, inplace = True)
cov_df_252_np = cov_df_252.to_numpy()
cov_df_252
# Out:
# Ticker #               861       895       747           1183      1389  \
#      Ticker #
# 251  861       2.308780e-04  0.000064  0.000024 -6.332419e-07  0.000084
#      895       6.351895e-05  0.001165 -0.000017  2.569938e-04  0.000286
#      747       2.428240e-05 -0.000017  0.001943  1.345425e-04  0.000020
#      1183     -6.332419e-07  0.000257  0.000135  1.044115e-03  0.000211
#      1389      8.371464e-05  0.000286  0.000020  2.111205e-04  0.000800
# ...                     ...       ...       ...           ...       ...
# 1509 1196      3.047874e-04  0.000373  0.000809  3.492820e-04  0.000479
#      163       3.736479e-04  0.000512  0.000679  3.559447e-04  0.000444
#      388       4.292569e-04  0.000721  0.001157  6.273019e-04  0.000618
#      610       8.807421e-04  0.001093  0.001623  1.088934e-03  0.001048
#      304       4.811334e-04  0.000603  0.000867  4.658249e-04  0.000644
#
# Ticker #           495       729       656       1479      675   ...  \
#      Ticker #                                                    ...
# 251  861       0.000063  0.000048  0.000021  0.000015 -0.000023  ...
#      895       0.000179  0.000217  0.000053  0.000045 -0.000023  ...
#      747       0.000077  0.000240  0.000124  0.000047  0.000142  ...
#      1183      0.000171  0.000193  0.000088  0.000020  0.000101  ...
#      1389      0.000173  0.000167  0.000064  0.000031  0.000081  ...
# ...                 ...       ...       ...       ...       ...  ...
# 1509 1196      0.000042  0.000931  0.000515  0.000899  0.000585  ...
#      163       0.000074  0.000919  0.000536  0.000675  0.000564  ...
#      388       0.000081  0.001152  0.000781  0.001006  0.000917  ...
#      610       0.000133  0.002666  0.001410  0.001484  0.001556  ...
#      304       0.000077  0.001411  0.000695  0.000872  0.000898  ...
#
# Ticker #           1113          505       189       910       1502      1196  \
#      Ticker #
# 251  861       0.000091 -5.820213e-07  0.000001  0.000101  0.000016  0.000042
#      895       0.000184  1.151779e-04  0.000200  0.000347  0.000053  0.000122
#      747       0.000174  5.135581e-05  0.000023  0.000050  0.000005  0.000042
#      1183      0.000063  2.349728e-04  0.000221  0.000217  0.000066  0.000135
#      1389      0.000115  1.769632e-04  0.000173  0.000286  0.000054  0.000093
# ...                 ...           ...       ...       ...       ...       ...
# 1509 1196      0.000547  1.033694e-03  0.000296  0.000701  0.000128  0.001205
#      163       0.000557  9.511365e-04  0.000674  0.000648  0.000144  0.000410
#      388       0.000723  1.237966e-03  0.000850  0.000590  0.000203  0.000602
#      610       0.001272  2.550709e-03  0.001677  0.001258  0.000297  0.001071
#      304       0.000822  1.114452e-03  0.000739  0.000858  0.000200  0.000530
#
# Ticker #           163       388       610       304
#      Ticker #
# 251  861       0.000047  0.000080  0.000060  0.000077
#      895       0.000347  0.000428  0.000142  0.000283
#      747      -0.000058  0.000159  0.000012 -0.000089
#      1183      0.000222  0.000264  0.000102  0.000057
#      1389      0.000258  0.000300  0.000138  0.000222
# ...                 ...       ...       ...       ...
# 1509 1196      0.000410  0.000602  0.001071  0.000530
#      163       0.000833  0.000637  0.001015  0.000616
#      388       0.000637  0.002150  0.001663  0.000868
#      610       0.001015  0.001663  0.006773  0.001239
#      304       0.000616  0.000868  0.001239  0.001590
#
# [125900 rows x 100 columns]

# %% [markdown]
# #### ii) Estimate the standard deviations of the portfolio over rw (from the last day in the rolling window).

# %%
#portfolio_weights
weights_q2_252 = portfolio_q2_cap.iloc[:, :].apply(lambda x: x.div(x.sum()), axis=1)
df_weights_q2_252 = weights_q2_252.drop(weights_q2_252.tail(1).index)
#        0.03070573])

# %% [markdown]
# #### iii) Using the market capitalization weights and returns (from the day following the last day in the rolling window) of your securities, calculate the one-day ahead return of the portfolio, $\tilde{r}_{p}$.

# %%
#getting one-day ahead returns array
dayahead252_port_ret_q2 = []
dayahead252_ret_q2 = portfolio_q2_ret.loc[252:1510].to_numpy()
dayahead252_w_q2 = weights_q2_252.loc[252:1510].to_numpy()
for i in range(0, len(dayahead252_w_q2)):
    dayahead252_port_ret_q2.append(np.multiply(dayahead252_ret_q2[i], dayahead252_w_q2[i]))
dayahead252_port_ret_q2_arr = np.sum(np.array(dayahead252_port_ret_q2), axis = 1)
dayahead252_port_ret_q2_arr
# Out:
# array([-0.01187761, -0.01687497, -0.00844107, ..., -0.0022362 ,
#         0.0004401 , -0.00969607])

# %% [markdown]
# #### iv) Calculate the standardized outcome, $\tilde{z}_{p}$, where $\tilde{z}_{p} = \frac{\tilde{r}_{p}}{\hat{\sigma}_{p}}$ where we make the simplifying assumption that $E[\tilde{r}_{p}] = 0$.

# %%
standardized_outcomes_252_q2 = dayahead252_port_ret_q2_arr / sd_port_252_arr
std_outcomes_252_q2 = pd.DataFrame(standardized_outcomes_252_q2)
std_outcomes_252_q2.index += 252
std_outcomes_252_q2.rename(columns={0: "Standardized Outcome"}, inplace = True)
std_outcomes_252_q2
# Out:
#       Standardized Outcome
# 252              -1.419925
# 253              -2.008991
# 254              -0.997745
# 255               0.437783
# 256              -0.201522
# ...                    ...
# 1506              0.191126
# 1507              0.060589
# 1508             -0.072687
# 1509              0.014311
# 1510             -0.315774
#
# [1259 rows x 1 columns]

# %% [markdown]
# ### Rolling Window 126

# %% [markdown]
# #### i) Generate a covariance matrixes for generated portfolio.

# %%
cov_df_126 = portfolio_q2_ret.rolling(126).cov()
cov_df_126.dropna(inplace = True)
cov_df_126.drop(cov_df_126.tail(100).index, inplace = True)
cov_df_126_np = cov_df_126.to_numpy()
cov_df_126
# Out:
# Ticker #           861       895       747       1183      1389      495   \
#      Ticker #
# 125  861       0.000240  0.000083  0.000066  0.000011  0.000073  0.000091
#      895       0.000083  0.001739 -0.000155  0.000373  0.000368  0.000155
#      747       0.000066 -0.000155  0.003010  0.000171 -0.000021  0.000128
#      1183      0.000011  0.000373  0.000171  0.001161  0.000284  0.000173
#      1389      0.000073  0.000368 -0.000021  0.000284  0.000833  0.000122
# ...                 ...       ...       ...       ...       ...       ...
# 1509 1196      0.000077  0.000157  0.000190  0.000138  0.000150  0.000030
#      163       0.000126  0.000253  0.000230  0.000194  0.000128  0.000107
#      388       0.000171  0.000285  0.000430  0.000215  0.000225  0.000048
#      610       0.000415  0.000271  0.000545  0.000345  0.000525  0.000172
#      304       0.000184  0.000287  0.000274  0.000210  0.000265  0.000057
#
# Ticker #           729       656       1479      675   ...      1113  \
#      Ticker #                                          ...
# 125  861       0.000065  0.000028  0.000015 -0.000006  ...  0.000094
#      895       0.000307  0.000053  0.000063 -0.000202  ...  0.000211
#      747       0.000372  0.000168  0.000053  0.000190  ...  0.000277
#      1183      0.000251  0.000110  0.000065  0.000052  ...  0.000149
#      1389      0.000212  0.000061  0.000058  0.000087  ...  0.000039
# ...                 ...       ...       ...       ...  ...       ...
# 1509 1196      0.000175  0.000195  0.000254  0.000161  ...  0.000171
#      163       0.000269  0.000238  0.000233  0.000226  ...  0.000266
#      388       0.000431  0.000287  0.000334  0.000376  ...  0.000360
#      610       0.000491  0.000558  0.000708  0.000397  ...  0.000491
#      304       0.000413  0.000260  0.000265  0.000334  ...  0.000411
#
# Ticker #           505       189       910       1502      1196      163   \
#      Ticker #
# 125  861      -0.000059  0.000010  0.000126  0.000012  0.000050  0.000061
#      895       0.000129  0.000165  0.000445  0.000056  0.000186  0.000498
#      747       0.000051  0.000041  0.000009  0.000008  0.000056 -0.000060
#      1183      0.000301  0.000161  0.000225  0.000065  0.000218  0.000250
#      1389      0.000206  0.000116  0.000245  0.000058  0.000113  0.000241
# ...                 ...       ...       ...       ...       ...       ...
# 1509 1196      0.000464  0.000068  0.000138  0.000076  0.000560  0.000173
#      163       0.000326  0.000339  0.000296  0.000093  0.000173  0.000393
#      388       0.000670  0.000660  0.000285  0.000129  0.000186  0.000318
#      610       0.001141  0.000295  0.000511  0.000223  0.000345  0.000509
#      304       0.000547  0.000697  0.000488  0.000104  0.000113  0.000299
#
# Ticker #           388       610       304
#      Ticker #
# 125  861       0.000067  0.000035  0.000080
#      895       0.000559  0.000163  0.000470
#      747       0.000096  0.000072 -0.000191
#      1183      0.000294  0.000035  0.000093
#      1389      0.000345  0.000107  0.000251
# ...                 ...       ...       ...
# 1509 1196      0.000186  0.000345  0.000113
#      163       0.000318  0.000509  0.000299
#      388       0.000913  0.000627  0.000405
#      610       0.000627  0.003626  0.000600
#      304       0.000405  0.000600  0.001065
#
# [138500 rows x 100 columns]

# %% [markdown]
# #### ii) Estimate the standard deviations of the portfolio over rw (from the last day in the rolling window).

# %%
#portfolio_weights
weights_q2_126 = portfolio_q2_cap.iloc[:, :].apply(lambda x: x.div(x.sum()), axis=1)
df_weights_q2_126 = weights_q2_126.drop(weights_q2_126.tail(1).index)
arr_weights_q2_126 = df_weights_q2_126.tail(1259).to_numpy()
df_weights_q2_126
# Out:
# Ticker #      861       895       747       1183      1389      495   \
# 0         0.004805  0.011026  0.000114  0.002565  0.000906  0.004899
# 1         0.004812  0.011038  0.000110  0.002542  0.000956  0.004859
# 2         0.005343  0.011223  0.000118  0.002563  0.000968  0.005227
# 3         0.005049  0.011096  0.000114  0.002650  0.000982  0.005199
# 4         0.005130  0.011688  0.000106  0.002670  0.001099  0.005264
# ...            ...       ...       ...       ...       ...       ...
# 1505      0.007734  0.022400  0.000624  0.004414  0.001582  0.007035
# 1506      0.007695  0.022449  0.000625  0.004420  0.001572  0.006995
# 1507      0.007622  0.022722  0.000605  0.004393  0.001565  0.006964
# 1508      0.007640  0.022801  0.000608  0.004395  0.001587  0.006949
# 1509      0.007562  0.023055  0.000593  0.004353  0.001596  0.006946
#
# Ticker #      729       656       1479      675   ...      1113      505   \
# 0         0.000261  0.014763  0.002665  0.000100  ...  0.000431  0.000231
# 1         0.000261  0.014413  0.002644  0.000097  ...  0.000458  0.000234
# 2         0.000253  0.014403  0.002635  0.000099  ...  0.000475  0.000219
# 3         0.000242  0.014251  0.002623  0.000099  ...  0.000455  0.000243
# 4         0.000250  0.014111  0.002622  0.000103  ...  0.000377  0.000259
# ...            ...       ...       ...       ...  ...       ...       ...
# 1505      0.000201  0.010435  0.003216  0.000304  ...  0.000448  0.000612
# 1506      0.000199  0.010402  0.003235  0.000298  ...  0.000447  0.000528
# 1507      0.000201  0.010451  0.003208  0.000300  ...  0.000445  0.000545
# 1508      0.000203  0.010533  0.003254  0.000300  ...  0.000443  0.000533
# 1509      0.000198  0.010522  0.003245  0.000308  ...  0.000452  0.000506
#
# Ticker #      189       910       1502      1196      163       388   \
# 0         0.000170  0.000359  0.000754  0.010359  0.003666  0.000518
# 1         0.000166  0.000384  0.000754  0.010232  0.003679  0.000533
# 2         0.000166  0.000403  0.000748  0.010305  0.003674  0.000570
# 3         0.000164  0.000397  0.000745  0.010193  0.003594  0.000599
# 4         0.000169  0.000399  0.000747  0.010232  0.003723  0.000599
# ...            ...       ...       ...       ...       ...       ...
# 1505      0.000438  0.000096  0.001869  0.008487  0.007285  0.001209
# 1506      0.000485  0.000098  0.001866  0.008484  0.007287  0.001204
# 1507      0.000474  0.000099  0.001893  0.008318  0.007267  0.001187
# 1508      0.000460  0.000101  0.001917  0.008390  0.007276  0.001193
# 1509      0.000457  0.000100  0.001894  0.008404  0.007440  0.001184
#
# Ticker #      610       304
# 0         0.002275  0.000487
# 1         0.002270  0.000511
# 2         0.002260  0.000527
# 3         0.002263  0.000513
# 4         0.002286  0.000543
# ...            ...       ...
# 1505      0.000407  0.000931
# 1506      0.000434  0.000948
# 1507      0.000422  0.000948
# 1508      0.000430  0.000947
# 1509      0.000431  0.000955
#
# [1510 rows x 100 columns]

# %%
sd_port_126 = []
for i in range(0, len(cov_df_126_np), 100):
    idx = 0
    sd_port_126.append(sd_portfolio(cov_df_126_np[i:i+100], arr_weights_q2_126[idx]))
    idx += 1
sd_port_126_arr = np.array(sd_port_126)
sd_port_126_arr
# Out:
# array([0.00827518, 0.0083208 , 0.00830922, ..., 0.01361003, 0.01361296,
#        0.01360251])

# %% [markdown]
# #### iii) Using the market capitalization weights and returns (from the day following the last day in the rolling window) of your securities, calculate the one-day ahead return of the portfolio, $\tilde{r}_{p}$.

# %%
#getting one-day ahead returns array
dayahead126_port_ret_q2 = []
dayahead126_ret_q2 = portfolio_q2_ret.loc[126:1510].to_numpy()
dayahead126_w_q2 = weights_q2_126.loc[126:1510].to_numpy()
for i in range(0, len(dayahead126_w_q2)):
    dayahead126_port_ret_q2.append(np.multiply(dayahead126_ret_q2[i], dayahead126_w_q2[i]))
dayahead126_port_ret_q2_arr = np.sum(np.array(dayahead126_port_ret_q2), axis = 1)
dayahead126_port_ret_q2_arr
# Out:
# array([-0.00986861,  0.0042113 , -0.00609825, ..., -0.0022362 ,
#         0.0004401 , -0.00969607])

# %% [markdown]
# #### iv) Calculate the standardized outcome, $\tilde{z}_{p}$, where $\tilde{z}_{p} = \frac{\tilde{r}_{p}}{\hat{\sigma}_{p}}$ where we make the simplifying assumption that $E[\tilde{r}_{p}] = 0$.

# %%
standardized_outcomes_126_q2 = dayahead126_port_ret_q2_arr / sd_port_126_arr
std_outcomes_126_q2 = pd.DataFrame(standardized_outcomes_126_q2)
std_outcomes_126_q2.index += 126
std_outcomes_126_q2.rename(columns={0: "Standardized Outcome"}, inplace = True)
std_outcomes_126_q2
# Out:
#       Standardized Outcome
# 126              -1.192556
# 127               0.506118
# 128              -0.733914
# 129               0.621606
# 130               0.203769
# ...                    ...
# 1506              0.430622
# 1507              0.136569
# 1508             -0.164305
# 1509              0.032330
# 1510             -0.712815
#
# [1385 rows x 1 columns]

# %% [markdown]
# ### Rolling Window 63

# %% [markdown]
# #### i) Generate a covariance matrixes for generated portfolio.

# %%
cov_df_63 = portfolio_q2_ret.rolling(63).cov()
cov_df_63.dropna(inplace = True)
cov_df_63.drop(cov_df_63.tail(100).index, inplace = True)
cov_df_63_np = cov_df_63.to_numpy()
cov_df_63
# Out:
# Ticker #           861       895       747       1183      1389      495   \
#      Ticker #
# 62   861       0.000378  0.000110  0.000031  0.000029  0.000090  0.000160
#      895       0.000110  0.002420 -0.000420  0.000287  0.000366  0.000087
#      747       0.000031 -0.000420  0.004627  0.000423 -0.000177  0.000232
#      1183      0.000029  0.000287  0.000423  0.000756  0.000292  0.000121
#      1389      0.000090  0.000366 -0.000177  0.000292  0.000974  0.000060
# ...                 ...       ...       ...       ...       ...       ...
# 1509 1196      0.000084  0.000091  0.000175  0.000088  0.000100  0.000039
#      163       0.000062  0.000265  0.000315  0.000237  0.000156  0.000091
#      388       0.000115  0.000231  0.000527  0.000249  0.000210  0.000087
#      610       0.000471  0.000310  0.000907  0.000459  0.000703  0.000171
#      304       0.000213  0.000302  0.000377  0.000244  0.000243  0.000124
#
# Ticker #           729       656       1479      675   ...      1113  \
#      Ticker #                                          ...
# 62   861       0.000043  0.000020  0.000005  0.000043  ...  0.000170
#      895       0.000265  0.000002  0.000055 -0.000318  ...  0.000130
#      747       0.000471  0.000208  0.000007  0.000586  ...  0.000430
#      1183      0.000206  0.000104  0.000105  0.000083  ...  0.000116
#      1389      0.000209 -0.000007  0.000071  0.000142  ... -0.000110
# ...                 ...       ...       ...       ...  ...       ...
# 1509 1196      0.000187  0.000114  0.000143  0.000057  ...  0.000158
#      163       0.000263  0.000252  0.000215  0.000185  ...  0.000323
#      388       0.000315  0.000282  0.000321  0.000287  ...  0.000380
#      610       0.000747  0.000624  0.000723  0.000190  ...  0.000682
#      304       0.000374  0.000324  0.000265  0.000143  ...  0.000449
#
# Ticker #           505       189       910       1502      1196      163   \
#      Ticker #
# 62   861      -0.000134  0.000042  0.000177  0.000005  0.000058  0.000088
#      895       0.000108  0.000254  0.000475  0.000023  0.000104  0.000522
#      747       0.000083  0.000010 -0.000232 -0.000031  0.000153 -0.000238
#      1183      0.000257  0.000025  0.000216  0.000059  0.000129  0.000144
#      1389      0.000302  0.000045  0.000294  0.000049  0.000066  0.000261
# ...                 ...       ...       ...       ...       ...       ...
# 1509 1196      0.000214  0.000023  0.000112  0.000060  0.000433  0.000133
#      163       0.000436  0.000306  0.000278  0.000095  0.000133  0.000377
#      388       0.000395  0.000501  0.000152  0.000147  0.000128  0.000341
#      610       0.001049  0.000697  0.000380  0.000302  0.000291  0.000568
#      304       0.000123  0.000724  0.000499  0.000173  0.000098  0.000371
#
# Ticker #           388       610       304
#      Ticker #
# 62   861       0.000211  0.000035  0.000149
#      895       0.000531  0.000107  0.000491
#      747      -0.000210 -0.000010 -0.000428
#      1183      0.000337  0.000104  0.000023
#      1389      0.000506  0.000082  0.000241
# ...                 ...       ...       ...
# 1509 1196      0.000128  0.000291  0.000098
#      163       0.000341  0.000568  0.000371
#      388       0.000983  0.000865  0.000481
#      610       0.000865  0.004405  0.000883
#      304       0.000481  0.000883  0.001071
#
# [144800 rows x 100 columns]

# %% [markdown]
# #### ii) Estimate the standard deviations of the portfolio over rw (from the last day in the rolling window).

# %%
#portfolio_weights
weights_q2_63 = portfolio_q2_cap.iloc[:, :].apply(lambda x: x.div(x.sum()), axis=1)
df_weights_q2_63 = weights_q2_63.drop(weights_q2_63.tail(1).index)
arr_weights_q2_63 = df_weights_q2_63.tail(1448).to_numpy()
df_weights_q2_63
# Out:
# Ticker #      861       895       747       1183      1389      495   \
# 0         0.004805  0.011026  0.000114  0.002565  0.000906  0.004899
# 1         0.004812  0.011038  0.000110  0.002542  0.000956  0.004859
# 2         0.005343  0.011223  0.000118  0.002563  0.000968  0.005227
# 3         0.005049  0.011096  0.000114  0.002650  0.000982  0.005199
# 4         0.005130  0.011688  0.000106  0.002670  0.001099  0.005264
# ...            ...       ...       ...       ...       ...       ...
# 1505      0.007734  0.022400  0.000624  0.004414  0.001582  0.007035
# 1506      0.007695  0.022449  0.000625  0.004420  0.001572  0.006995
# 1507      0.007622  0.022722  0.000605  0.004393  0.001565  0.006964
# 1508      0.007640  0.022801  0.000608  0.004395  0.001587  0.006949
# 1509      0.007562  0.023055  0.000593  0.004353  0.001596  0.006946
#
# Ticker #      729       656       1479      675   ...      1113      505   \
# 0         0.000261  0.014763  0.002665  0.000100  ...  0.000431  0.000231
# 1         0.000261  0.014413  0.002644  0.000097  ...  0.000458  0.000234
# 2         0.000253  0.014403  0.002635  0.000099  ...  0.000475  0.000219
# 3         0.000242  0.014251  0.002623  0.000099  ...  0.000455  0.000243
# 4         0.000250  0.014111  0.002622  0.000103  ...  0.000377  0.000259
# ...            ...       ...       ...       ...  ...       ...       ...
# 1505      0.000201  0.010435  0.003216  0.000304  ...  0.000448  0.000612
# 1506      0.000199  0.010402  0.003235  0.000298  ...  0.000447  0.000528
# 1507      0.000201  0.010451  0.003208  0.000300  ...  0.000445  0.000545
# 1508      0.000203  0.010533  0.003254  0.000300  ...  0.000443  0.000533
# 1509      0.000198  0.010522  0.003245  0.000308  ...  0.000452  0.000506
#
# Ticker #      189       910       1502      1196      163       388   \
# 0         0.000170  0.000359  0.000754  0.010359  0.003666  0.000518
# 1         0.000166  0.000384  0.000754  0.010232  0.003679  0.000533
# 2         0.000166  0.000403  0.000748  0.010305  0.003674  0.000570
# 3         0.000164  0.000397  0.000745  0.010193  0.003594  0.000599
# 4         0.000169  0.000399  0.000747  0.010232  0.003723  0.000599
# ...            ...       ...       ...       ...       ...       ...
# 1505      0.000438  0.000096  0.001869  0.008487  0.007285  0.001209
# 1506      0.000485  0.000098  0.001866  0.008484  0.007287  0.001204
# 1507      0.000474  0.000099  0.001893  0.008318  0.007267  0.001187
# 1508      0.000460  0.000101  0.001917  0.008390  0.007276  0.001193
# 1509      0.000457  0.000100  0.001894  0.008404  0.007440  0.001184
#
# Ticker #      610       304
# 0         0.002275  0.000487
# 1         0.002270  0.000511
# 2         0.002260  0.000527
# 3         0.002263  0.000513
# 4         0.002286  0.000543
# ...            ...       ...
# 1505      0.000407  0.000931
# 1506      0.000434  0.000948
# 1507      0.000422  0.000948
# 1508      0.000430  0.000947
# 1509      0.000431  0.000955
#
# [1510 rows x 100 columns]

# %%
sd_port_63 = []
for i in range(0, len(cov_df_63_np), 100):
    idx = 0
    sd_port_63.append(sd_portfolio(cov_df_63_np[i:i+100], arr_weights_q2_63[idx]))
    idx += 1
sd_port_63_arr = np.array(sd_port_63)
sd_port_63_arr
# Out:
# array([0.00910965, 0.0092089 , 0.0092066 , ..., 0.01296528, 0.01296553,
#        0.01294103])

# %% [markdown]
# #### iii) Using the market capitalization weights and returns (from the day following the last day in the rolling window) of your securities, calculate the one-day ahead return of the portfolio, $\tilde{r}_{p}$.

# %%
#getting one-day ahead returns array
dayahead63_port_ret_q2 = []
dayahead63_ret_q2 = portfolio_q2_ret.loc[63:1510].to_numpy()
dayahead63_w_q2 = weights_q2_63.loc[63:1510].to_numpy()
for i in range(0, len(dayahead63_w_q2)):
    dayahead63_port_ret_q2.append(np.multiply(dayahead63_ret_q2[i], dayahead63_w_q2[i]))
dayahead63_port_ret_q2_arr = np.sum(np.array(dayahead63_port_ret_q2), axis = 1)
dayahead63_port_ret_q2_arr
# Out:
# array([ 0.01076997,  0.00706012, -0.00490281, ..., -0.0022362 ,
#         0.0004401 , -0.00969607])

# %% [markdown]
# #### iv) Calculate the standardized outcome, $\tilde{z}_{p}$, where $\tilde{z}_{p} = \frac{\tilde{r}_{p}}{\hat{\sigma}_{p}}$ where we make the simplifying assumption that $E[\tilde{r}_{p}] = 0$.

# %%
standardized_outcomes_63_q2 = dayahead63_port_ret_q2_arr / sd_port_63_arr
std_outcomes_63_q2 = pd.DataFrame(standardized_outcomes_63_q2)
std_outcomes_63_q2.index += 63
std_outcomes_63_q2.rename(columns={0: "Standardized Outcome"}, inplace = True)
std_outcomes_63_q2
# Out:
#       Standardized Outcome
# 63                1.182259
# 64                0.766663
# 65               -0.532532
# 66               -0.840335
# 67               -0.587595
# ...                    ...
# 1506              0.444428
# 1507              0.140960
# 1508             -0.172476
# 1509              0.033944
# 1510             -0.749250
#
# [1448 rows x 1 columns]

# %% [markdown]
# ## b) Compute bias statistics.

# %%
bias_stat_q2_504 = np.std(standardized_outcomes_504_q2)
bias_stat_q2_252 = np.std(standardized_outcomes_252_q2)
bias_stat_q2_126 = np.std(standardized_outcomes_126_q2)
bias_stat_q2_63 = np.std(standardized_outcomes_63_q2)
print(bias_stat_q2_504, bias_stat_q2_252, bias_stat_q2_126, bias_stat_q2_63)
# Out:
# 1.3204917779811967 1.0903814842318365 1.018551730690755 0.9926056945556908

# %% [markdown]
# Rolling window 63 gives closest bias statistic to 1. Idk why.
